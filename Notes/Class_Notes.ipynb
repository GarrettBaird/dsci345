# %%
import numpy.random as rng
import numpy as np

# %% [markdown]
# # General
# **Office Hours:**
# MW 11:30 - 12:30 -> Fenton 310
#
# ### Notes
# - *Quizzes every class*
# - Lecture notes available on Canvas
#
# # To-Do
# - Connect the folder to github
# - Transcribe notes into notebook

# %% [markdown]
# # Probablilty Models
# - Mathamatical model for chacnce phenoman
#     - Example: Coin flips
#         - Toss 1 coin
#         - outcome space(sample space)(S)
#             - S = {H,T}
#         - How are probabilites assigned?
#             - Fair coin: p(H) = P(T) = 1/2
#             - Bias Coin: p(H) = P
#                          P(T) = 1 - P
#         - P is a parameter, if p is unkown, good may be to estimate p from data.
#         - Data may come from many coin tosses: T,H,H,T,H,....,T
#         - Probabilty model (Theortical Construct)
#             Data assuming one from this are obeservable
#             #H/100 -> close to P
#
#         **Toss the coin 10 Times**
#             all finite seq of lenght 10 using H,T Only
#             S = {2^10}: there are 2 possiblites, for 10 tosses
#             ie. 2*2*2...*2 = 2^10
#
#                 **Mult Rule**
#                     If a possible for first recored to around...? *Check txt book later
#                         # ordered pairs = a*b
#
#         **Fair coin tossed 10 Times**
#             Each 2^10 outocomes are equally likely, so the probabilty of any given sequence will be
#                 1/2^10
#
#     **Event**
#     A = {Exactly one H}
#     - Its a collection of outcomes in the event space
#     if all outcomes are equally as likely:
#         P(A) = #outcomes in A / Total # Outcomes
#         = 10 / 2 ^ 10
#
#     In general, A prob P on a single space assigns probabilites to events, subsets S
#     A < S  P(A)
#     If 5 is finite, prob assighed to outcomes
#         A < S,  P(A) = sum(S in A)P(a)
#
#     P_i = > 0  Sum(P_i) = 1
#     0<P(A)< 1
#
#     **Rules From P**
#     1. A probability must be between 0 -> 1
#     2. If A and B are disjoint
#
#     ***Disjoined***
#     Toss coin 10 times
#         A = {Exactily one is H}
#         B = {H on 1rst Toss}
#             2 ^ 9
#         P(B) = 2^9 / 2 ^ 10 = 1/2
#
#     Defn: ***A,B disjoint if they have no outcomes in common***
#
#     2. If A and B are disjoint then
#         P(A|B) = P(A) + P(B) *find the union symbol
#
#     3. P(S) = 1: the probability of the space is 1 ie something has to happen
#
#
#
# A Compliment = All outcomes not in A
# P(A compliment) = 1 - P(A)
# P(A|A Compliment ) = S = 1 P(A) + P(A compliment) off the second rules
#
# P(at least one 1 head) = 1 - P(no heads) = 1 - (1/2^10)
#
#
# P(Rains today) = 0.9
# P(Rains Tommorow) = 0.8
# P(Rains on both days) = 0.9
# P(Rains on today or tommorow) = ?
#     A - rain today
#     B - Rains tommorow
# P(AUB) = P(A) + P(B) Does not work due to rule 2: they are not disjoint, so
# P(AUB) = P(A) + P(B) - P(A cap B)
# = .9 + .8 - .9 =  .8 chance of rain for both days
#
#
# Independence
#
# ex. Toss a bias coin 10 times
#     p = 0.6
#     All outocomes are not equally balanced
#
#     Events A and B are independt if
#     P(A cap B) = P(A)P(B)
#
#     Suppose toss fair coin twice:
#         S = {HH,TT,HT,TH} # Four outcomes
#         A = {1rst toss is a H}    B = {2nd Toss is H}
#         Are A and B Independent?
#             P(A cap B) = P(HH) = 1/4 | .25
#             P(A)P(B) = 2/4 * 2/4 = 1/4 | .25
#         Verifed that A and B are independent
#
#     If you toss a biased coin 3 tiems (P = .6) an(d assume the tosses are independent:
#         P(HHH) = P(H)P(H)P(H) = 0.6 ** 3
#         P(HTH) = P(H)P(T)P(H) = (0.6 ** 2) * P(.4)
#
# Generalized:
#  Toss a p - Biased coin n times
#     P(Exactly k H's)
#         n - k T's
#     P(H --HT--T) = P^K (1-p)^(n-k)
#
#     How many sequences w/ K heads and n-k trails?
#         (nk) = n!/K!(n-k)! Binomial coeff
#         (nk) = # ways to pick k things from n things
#
#         P(exactly k H's) = (nk) p^k (1-p)^(n-k) : binomial random varibles
#
# nxt random Variables
